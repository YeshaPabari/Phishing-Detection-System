# %%
from google.colab import drive
drive.mount('/content/drive')

BASE = '/content/drive/MyDrive/Phishing_Detection_Project'
print(BASE)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Phishing_Detection_Project

# %%
import os

folders = [
    'data',
    'data/raw',
    'data/processed',
    'models',
    'outputs',
    'reports',
    'notebooks'
]

for f in folders:
    os.makedirs(BASE + '/' + f, exist_ok=True)

print("Folders created successfully")
# Out:
# Folders created successfully

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn joblib -q

print("Libraries installed")
# Out:
# Libraries installed
